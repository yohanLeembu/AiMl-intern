# %%
x = 10 
learning_rate = 0.1

for i in range(50):
    gradient = 2 * x
    x = x - learning_rate * gradient

    print("Iteration:", i + 1 , "x:", x)
# Out:
# Iteration: 1 x: 8.0
# Iteration: 2 x: 6.4
# Iteration: 3 x: 5.12
# Iteration: 4 x: 4.096
# Iteration: 5 x: 3.2768
# Iteration: 6 x: 2.62144
# Iteration: 7 x: 2.0971520000000003
# Iteration: 8 x: 1.6777216000000004
# Iteration: 9 x: 1.3421772800000003
# Iteration: 10 x: 1.0737418240000003
# Iteration: 11 x: 0.8589934592000003
# Iteration: 12 x: 0.6871947673600002
# Iteration: 13 x: 0.5497558138880001
# Iteration: 14 x: 0.43980465111040007
# Iteration: 15 x: 0.35184372088832006
# Iteration: 16 x: 0.281474976710656
# Iteration: 17 x: 0.22517998136852482
# Iteration: 18 x: 0.18014398509481985
# Iteration: 19 x: 0.14411518807585588
# Iteration: 20 x: 0.11529215046068471
# Iteration: 21 x: 0.09223372036854777
# Iteration: 22 x: 0.07378697629483821
# Iteration: 23 x: 0.05902958103587057
# Iteration: 24 x: 0.04722366482869646
# Iteration: 25 x: 0.037778931862957166
# Iteration: 26 x: 0.030223145490365734
# Iteration: 27 x: 0.024178516392292588
# Iteration: 28 x: 0.01934281311383407
# Iteration: 29 x: 0.015474250491067256
# Iteration: 30 x: 0.012379400392853806
# Iteration: 31 x: 0.009903520314283045
# Iteration: 32 x: 0.007922816251426436
# Iteration: 33 x: 0.006338253001141149
# Iteration: 34 x: 0.00507060240091292
# Iteration: 35 x: 0.0040564819207303355
# Iteration: 36 x: 0.0032451855365842686
# Iteration: 37 x: 0.002596148429267415
# Iteration: 38 x: 0.002076918743413932
# Iteration: 39 x: 0.0016615349947311456
# Iteration: 40 x: 0.0013292279957849164
# Iteration: 41 x: 0.001063382396627933
# Iteration: 42 x: 0.0008507059173023465
# Iteration: 43 x: 0.0006805647338418772
# Iteration: 44 x: 0.0005444517870735017
# Iteration: 45 x: 0.0004355614296588014
# Iteration: 46 x: 0.0003484491437270411
# Iteration: 47 x: 0.00027875931498163285
# Iteration: 48 x: 0.00022300745198530628
# Iteration: 49 x: 0.00017840596158824503
# Iteration: 50 x: 0.00014272476927059603

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 5, 50)
plt.plot(x, label="y = x^2")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.title("Iteration")
plt.show()

# %%
#trying to understanding all

# Dataset
X = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([3, 5, 7, 9, 11], dtype=float)

# Initial parameters
w = 0
b = 0

# Training settings
learning_rate = 0.01
epochs = 1000

loss_history = []

# Training loop
for epoch in range(epochs):

    # Prediction
    predictions = w * X + b

    # Loss
    loss = np.mean((predictions - y) ** 2)

    # Store loss
    loss_history.append(loss)

    # Calculate gradients
    n = len(X)

    dw = (2 / n) * np.sum(X * (predictions - y))
    db = (2 / n) * np.sum(predictions - y)

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Print progress
    if epoch % 100 == 0:
        print(
            f"Epoch {epoch}: "
            f"Loss = {loss:.4f}, "
            f"w = {w:.4f}, "
            f"b = {b:.4f}"
        )

print("\nFinal parameters:")
print("w =", w)
print("b =", b)
