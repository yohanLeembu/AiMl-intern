# %%
import numpy as np

# %%
numbers =  np.array([10, 20, 30, 40, 50])

# %%
myarray = np.array([5 , 15, 25, 35, 45])
print(myarray)

# %%
arr1 = np.array([10, 20, 30, 40])

print(arr1)

# %%
arr2 = np.array([
    [10, 20],
    [30, 40]
])

print(arr2)

# %%
arr3 = np.array([
    [
        [1, 2],
        [3, 4]
    ]
])

print(arr3)
# Out:
# [[[1 2]
#   [3 4]]]
