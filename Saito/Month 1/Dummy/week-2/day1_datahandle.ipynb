# %%
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 3.0.5
# NumPy version: 2.5.1

# %%
data = {
    "Name":["John","Alice","Mike"],
    "Age":[22,25,20]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0   John   22
# 1  Alice   25
# 2   Mike   20

# %%
data = {
    "Name":["John","Alice","Mike"],
    "Age":[22,25,20]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0   John   22
# 1  Alice   25
# 2   Mike   20

# %%
df["Age"]
# Out:
# 0    22
# 1    25
# 2    20
# Name: Age, dtype: int64

# %%
df[["Name","Age"]]
# Out:
#     Name  Age
# 0   John   22
# 1  Alice   25
# 2   Mike   20

# %%
df.iloc[0]

df.loc[0]
# Out:
# Name    John
# Age       22
# Name: 0, dtype: object

# %%
df["Age After 5 Years"] = df["Age"] + 5

# %%
df.drop(columns=["Age After 5 Years"])
# Out:
#     Name  Age
# 0   John   22
# 1  Alice   25
# 2   Mike   20

# %%
df.sort_values("Age")
# Out:
#     Name  Age  Age After 5 Years
# 2   Mike   20                 25
# 0   John   22                 27
# 1  Alice   25                 30

# %%
df.reset_index(drop=True)
# Out:
#     Name  Age  Age After 5 Years
# 0   John   22                 27
# 1  Alice   25                 30
# 2   Mike   20                 25
